# %%
# Importing pandas with alice Name pd
import pandas as pd

order_data = pd.read_excel(r"D:\pandas_learing\IPL_Project\Sample - Superstore.xls",sheet_name ="Orders")
order_data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11      IInd Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11      IInd Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16      IInd Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
return_data = pd.read_excel(r"D:\pandas_learing\IPL_Project\Sample - Superstore.xls",sheet_name ="Returns")
return_data.head()
# Out:
#   Returned        Order ID
# 0      Yes  CA-2017-153822
# 1      Yes  CA-2017-129707
# 2      Yes  CA-2014-152345
# 3      Yes  CA-2015-156440
# 4      Yes  US-2017-155999

# %%
return_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Returned  296 non-null    object
#  1   Order ID  296 non-null    object
# dtypes: object(2)
# memory usage: 4.8+ KB

# %%
merge_data = pd.merge(return_data,order_data,on="Order ID",how="left")
merge_data.head()
# Out:
#   Returned        Order ID  Row ID Order Date  Ship Date       Ship Mode  \
# 0      Yes  CA-2017-153822    6971 2017-09-19 2017-09-25  Standard Class
# 1      Yes  CA-2017-153822    6972 2017-09-19 2017-09-25  Standard Class
# 2      Yes  CA-2017-153822    6973 2017-09-19 2017-09-25  Standard Class
# 3      Yes  CA-2017-153822    6974 2017-09-19 2017-09-25  Standard Class
# 4      Yes  CA-2017-129707    5434 2017-04-25 2017-04-29  Standard Class
#
#   Customer ID  Customer Name   Segment        Country  ... Postal Code Region  \
# 0    AB-10105  Adrian Barton  Consumer  United States  ...       85023   West
# 1    AB-10105  Adrian Barton  Consumer  United States  ...       85023   West
# 2    AB-10105  Adrian Barton  Consumer  United States  ...       85023   West
# 3    AB-10105  Adrian Barton  Consumer  United States  ...       85023   West
# 4    LH-16750   Larry Hughes  Consumer  United States  ...       85224   West
#
#         Product ID         Category Sub-Category  \
# ...

# %%
merge_data_customer_list = merge_data["Customer Name"].drop_duplicates().reset_index()
#merge_data_customer_list = merge_data_customer_list.drop("index")
merge_data_customer_list.head(10)
# Out:
#    index    Customer Name
# 0      0    Adrian Barton
# 1      4     Larry Hughes
# 2      5         Shui Tom
# 3      7  Matt Hagelstein
# 4      8       Jay Kimmel
# 5     10   Helen Andreada
# 6     12     Greg Guthrie
# 7     18    Ionia McGrath
# 8     19    Cynthia Voltz
# 9     21   Michael Nguyen

# %%
merge_data.tail()
# Out:
#     Returned        Order ID  Row ID Order Date  Ship Date       Ship Mode  \
# 795      Yes  CA-2016-105585     993 2016-08-26 2016-08-27     First Class
# 796      Yes  CA-2016-105585     994 2016-08-26 2016-08-27     First Class
# 797      Yes  CA-2016-148796     418 2016-04-14 2016-04-18  Standard Class
# 798      Yes  CA-2015-149636    7717 2015-01-06 2015-01-12  Standard Class
# 799      Yes  CA-2015-149636    7718 2015-01-06 2015-01-12  Standard Class
#
#     Customer ID     Customer Name    Segment        Country  ... Postal Code  \
# 795    RF-19735      Roland Fjeld   Consumer  United States  ...       95123
# 796    RF-19735      Roland Fjeld   Consumer  United States  ...       95123
# 797    PB-19150      Philip Brown   Consumer  United States  ...       90004
# 798    SP-20620  Stefania Perrino  Corporate  United States  ...       80906
# 799    SP-20620  Stefania Perrino  Corporate  United States  ...       80906
#
# ...

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Returned       800 non-null    object
#  1   Order ID       800 non-null    object
#  2   Row ID         800 non-null    int64
#  3   Order Date     800 non-null    datetime64[ns]
#  4   Ship Date      800 non-null    datetime64[ns]
#  5   Ship Mode      800 non-null    object
#  6   Customer ID    800 non-null    object
#  7   Customer Name  800 non-null    object
#  8   Segment        800 non-null    object
#  9   Country        800 non-null    object
#  10  City           800 non-null    object
#  11  State          800 non-null    object
#  12  Postal Code    800 non-null    int64
#  13  Region         800 non-null    object
#  14  Product ID     800 non-null    object
#  15  Category       800 non-null    object
#  16  Sub-Category   800 non-null    object
# ...

# %%
grouping = merge_data.groupby("Region")["Sales"].sum()
grouping.head()
# Out:
# Region
# Central     14006.9794
# East        41705.1440
# South       17309.0970
# West       107483.0575
# Name: Sales, dtype: float64

# %%
segment = merge_data.groupby("Segment")["Sales"].sum()
segment.head()
# Out:
# Segment
# Consumer       105385.2523
# Corporate       51912.0436
# Home Office     23206.9820
# Name: Sales, dtype: float64

# %%
seg_region  = merge_data.groupby(["Region","Segment"])["Sales"].sum().reset_index()
print(seg_region)
# Out:
#      Region      Segment       Sales
# 0   Central     Consumer   8230.5248
# 1   Central    Corporate   3627.4456
# 2   Central  Home Office   2149.0090
# 3      East     Consumer  27227.8800
# 4      East    Corporate  10317.9950
# 5      East  Home Office   4159.2690
# 6     South     Consumer   8473.5410
# 7     South    Corporate   7128.2160
# 8     South  Home Office   1707.3400
# 9      West     Consumer  61453.3065
# 10     West    Corporate  30838.3870
# 11     West  Home Office  15191.3640

# %%
merge_data.tail()
# Out:
#     Returned        Order ID  Row ID Order Date  Ship Date       Ship Mode  \
# 795      Yes  CA-2016-105585     993 2016-08-26 2016-08-27     First Class
# 796      Yes  CA-2016-105585     994 2016-08-26 2016-08-27     First Class
# 797      Yes  CA-2016-148796     418 2016-04-14 2016-04-18  Standard Class
# 798      Yes  CA-2015-149636    7717 2015-01-06 2015-01-12  Standard Class
# 799      Yes  CA-2015-149636    7718 2015-01-06 2015-01-12  Standard Class
#
#     Customer ID     Customer Name    Segment        Country  ... Postal Code  \
# 795    RF-19735      Roland Fjeld   Consumer  United States  ...       95123
# 796    RF-19735      Roland Fjeld   Consumer  United States  ...       95123
# 797    PB-19150      Philip Brown   Consumer  United States  ...       90004
# 798    SP-20620  Stefania Perrino  Corporate  United States  ...       80906
# 799    SP-20620  Stefania Perrino  Corporate  United States  ...       80906
#
# ...

# %%
date_wish  = merge_data.groupby(["Order Date","Segment"])["Sales"].sum().reset_index()
print(date_wish)
# Out:
#     Order Date      Segment      Sales
# 0   2014-01-20     Consumer    38.6600
# 1   2014-02-23  Home Office    11.3640
# 2   2014-03-17    Corporate   103.5000
# 3   2014-03-18  Home Office  1198.3300
# 4   2014-04-06    Corporate   199.9900
# ..         ...          ...        ...
# 280 2017-12-22     Consumer  1090.3480
# 281 2017-12-25     Consumer   160.1620
# 282 2017-12-28     Consumer   106.0208
# 283 2017-12-29     Consumer    88.0600
# 284 2017-12-30    Corporate    34.6240
#
# [285 rows x 3 columns]
